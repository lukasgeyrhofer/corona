# %%
import numpy as np
import pandas as pd

import gspread
from oauth2client.service_account import ServiceAccountCredentials

import pickle
import os


from googleapiclient.discovery import build
from google_auth_oauthlib.flow import InstalledAppFlow
from google.auth.transport.requests import Request


from imp import reload
import measureclass as mc; reload(mc);

# %%
#data = pd.read_csv('https://drive.google.com/file/d/10FX8q7Uxb-oC2jf1zd-8U0Sd5H9HHvqU/view')


measures = mc.COVID19_measures(only_first_dates = True, measure_level = 2, extend_measure_names = True)

# %%
for c,md in measures:
    print(c)
    for k,v in md.items():
        print('   {}: '.format(k) + ', '.join(v))
    #print(md)
# Out:
# Thailand
#    Healthcare and public health capacity - Activate emergency response mechanisms: 2020-02-26
#    Healthcare and public health capacity - Activate healthcare capacity: 2020-01-07
#    Case identification, contact tracing and related measures - Airport health check: 2020-01-03
#    Travel restriction - Airport restriction: 2020-02-17
#    Travel restriction - Cancellation of international flights: 2020-02-28
#    Social distancing - Closure of educational institutions: 2020-03-17
#    Resource allocation - Crisis management plans: 2020-03-05
#    Travel restriction - Denial entry to boats with more than 100 passengers: 2020-02-11
#    Risk communication - Educate and actively communicate with the public: 2020-01-07
#    Risk communication - Encourage self-initiated quarantine: 2020-03-01
#    Healthcare and public health capacity - Enhance healthcare capacity: 2020-03-16
#    Healthcare and public health capacity - Enhance laboratory testing: 2020-02-18
# ...
